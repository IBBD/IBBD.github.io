# %% [markdown]
# # 零基础入门Python数据分析：第一课

# %% [markdown]
# ## 1. Python环境安装与基础使用：Anaconda
#
# Anaconda是专注于数据分析的Python发行版本，包含了conda、Python等190多个科学包及其依赖项，俗称“Notebook”。
#
# - 下载安装Anaconda：https://mirrors.tuna.tsinghua.edu.cn/help/anaconda/ ，找到最新的适合自己的最新版本，如64位windows：https://mirrors.tuna.tsinghua.edu.cn/anaconda/archive/Anaconda3-2020.02-Windows-x86_64.exe （如果是32位系统，需要下载对应的版本）
# - 启动运行
# - 界面基本介绍
# - 创建目录与文件
# - 上传与下载文件
# - 重命名文件
# - 移动文件
# - 删除文件
#
# 作为分析师，对于该工具不必过于纠结，从使用角度出发即可，作为入门，重点就几点：
#
# - 安装与启动
# - 基础的文件操作
#
# 至于其他的，其实往往都不是必须的。
#
# 新建一个Python notebook文件，其后缀名是.ipynb，对于notebook文件和我们平时在电脑上看到的有点不一样，这个文件会有一个“运行”的状态，点击打开之后，文件列表里小图标就会变绿，这就表示文件已经处于运行状态。选中文件之后，点击“shutdown”会停止运行，停止运行之后，才能进行下载等操作。

# %% [markdown]
# ### 1.1 Anaconda编辑界面的基础用法
#
# - 菜单栏
# - 工具栏
#
# 这个界面时非常常用的，熟练使用非常有必要

# %% [markdown]
# ## 2. Python基础语法
#
# 基础教程：https://www.runoob.com/python/python-tutorial.html
#
# ### 2.1 编程两个最基础的概念之一：语句
#
# - 在python中，通常一行写一个语句，在运行的时候，会一行一行的运行
# - 在语句中，如果出现#号，则后面的为注释部分，通常是用于方便人的理解，不会被执行
# - print是一个函数，可以用于打印输出一个或者多个变量的值

# %%
# 井号开头的行是注释
# 最简单的应用
# print是python的一个语句，用来打印一个或者多个值
print("Hello, World!")
print("你好，世界!")

# %%
# notebook的特殊用法
"Hello World!"
"你好，世界!"

# %% [markdown]
# ### 2.2 编程两个最基础的概念之二：变量
#
# 我们所说的变量，由变量名和值组成，变量名就像一个人的名字，而值就相当于那个人本身，当然那个人可以叫张三，也可以叫李四，但是都是指同一个人。我们给那个人起名叫张三的过程，放到编程中就叫赋值，即用一个变量名来代表某个值。
#
# - 等号是一个赋值符号，左边的是变量名，后边的是值。一次赋值就是一个语句
# - 变量名是区分大小写的
# - 变量名可以重复进行赋值
#
# 例如一个人的年龄是18岁，那么我们可以定义一个age变量：
#
# ![image.png](attachment:image.png)
#
# 标识符就是变量名。

# %%
# 定义
# 下面定义了变量a和b，并分别调用print函数进行打印
a = 1
print(a)    # 观察变量a的值
b = 1.2
print(b)    # 观察变量b的值

# 注意 变量名是区分大小写的
# 例如下面定义的就是两个变量，虽然它们的值都是1
a = 1
A = 1

# 可以重复赋值
a = 1
print(a)     # 这里会打印 1
a = 1.2
print(a)     # 这里会打印 1.2

# %% [markdown]
# ### 2.3 同时赋值多个变量
#
# 前面我们都是一行语句，赋值一个变量，但是其实在python中，在一行语句中是可以同时赋值多个变量的。

# %%
# 在一行同时定义a和b
a, b = 1, 2
print(a)     # 输出1
print(b)     # 输出2

# 有了这样的语法，要实现a和b的交换就非常简洁
a, b = b, a
print(a)     # 输出2
print(b)     # 输出1

# %% [markdown]
# ## 3. 基础变量类型
#
# 我们平时接触的数据，可能也会有几种类型，例如整数，小数，文本等，我们学习Python，首先就是需要一些基础的变量类型。
#
# 下面列表就是在Python里常见的数据类型：
#
# - int（整型）
# - float（浮点型）
# - bool（布尔值）
# - None（空类型）
# - str（字符串）
# - list（列表）
# - tuple（元组）
# - set（集合）
# - dict（字典）
#
# 这次课只讲前面三种基础的类型。

# %% [markdown]
# ### 3.1 整型与浮点型
#
# - 整型简单理解就是整数，包括正整数，负整数和0
# - 浮点型简单理解就是小数，当然也有正数，负数和0了
# - 整型和浮点型是可以直接做四则运算的

# %% [markdown]
# #### 3.1.1 定义与四则运算

# %%
# 定义
# 下面定义了变量a和b，并分别调用print函数进行打印
a = 1        # 定义整型变量
print(a)
b = 1.2      # 定义浮点型变量
print(b)

# %%
# 可以同时打印多个值
print(a, b)

# %%
# 整型浮点型的四则运算：加减乘除
c = a + b
print(c)

a = 1
b = 2
c = 3
c = (1+2)*3     # 可以使用小括号组合运算的优先级
print(c)

# %% [markdown]
# #### 3.1.2 常用的几个函数
#
# - abs：求绝对值
# - int：取整
# - round：四舍五入

# %%
a = -1.3
print('a的绝对值：', abs(a))

a = 3.58
print('a取整: ', int(a))
print('a四舍五入：', round(a))

# %% [markdown]
# ### 3.2 布尔型：bool

# %%
# 布尔值就真和假两个值：True, False
c = True
print(c)

d = False
print(d)

# %%
# 布尔型的基本运算
print(c and d)
print(c or d)
print(not c)

# 布尔型运算也可以通过小括号进行组合优先级
e = True
print(c and (e or d))

# 对其他类型做逻辑运算
# 非0值为True，0值为False
# 注意：通常很少这样使用，强制类型转换很容易写出不好维护的程序
a = 1
print(a, not a)

e = 0
print(e, not e)
print(a and e)    # 输出的是后面的值(好吧，我也没弄清楚这里为何不进行逻辑运算了)

# %% [markdown]
# 注意：虽然在python中，不同类型的值其实是可以进行自动类型转换的，例如整数0在判断布尔值时，其值为False，但是最好不要这样去使用，很容易留下大坑。

# %%
# 比较运算符
# 比较运算符得到的是布尔值，True或者False
print(a, e, a > e)
print(a, e, a >= e)
print(a, e, a < e)
print(a, e, a <= e)
print(a, e, a != e)

# %%
a = 1
b = 2
c = 3

# 运算优先级：四则运算优先级高于比较运算符
# Python在解释执行的时候，会先对优先级高的部分进行求值
print(a, b, c, a + b < c)
print(a, b, c, a < b * c)

# 比较符可以连写，这是python比较特有的
print(a, b, c, a < b < c)

# %% [markdown]
# ### 3.3 空类型 ：None
#
# 空类型只有一个值：None，在比较的时候经常会用到。

# %%
a = None

# 判断变量值是否为None
print(a == None)

# 通常我们使用下面的写法：is
print(a is None)
